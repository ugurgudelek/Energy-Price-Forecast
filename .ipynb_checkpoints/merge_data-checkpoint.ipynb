# %% [markdown]
# Lets fetch data from url

# %%
import pandas as pd
import os

def get_data(year,month,region='QLD', path='data'):
    # regions : QLD,NSW,VIC,SA
    # first date for data : January 1999
    available_regions = ['QLD','NSW','VIC','SA']
    available_months = ['01','02','03','04','05','06','07','08','09','10','11','12']
    available_years = [str(i) for i in range(1999,2017)]


    if region not in available_regions:
        raise Exception('Region not found!')

    if year not in available_years:
        raise Exception('Year not found!')

    if month not in available_months:
        raise Exception('Month not found! Check 02-2 issue')


    url_csv = "https://www.aemo.com.au/aemo/data/nem/priceanddemand/PRICE_AND_DEMAND_{}{}_{}1.csv".format(year,month,region)
    filename = "{}_{}_{}.csv".format(year, month, region)
    path_region = path+'/'+region

    # if folder not found in current dir
    if region not in os.listdir(path):
        os.makedirs(path_region)

    # if not already exist
    if filename not in os.listdir(path_region):
        print('Fetching url...')
        print(url_csv)
        df = pd.read_csv(url_csv)

        print('Saving...', filename)
        df.to_csv("{}/{}/{}_{}_{}.csv".format(path,region,year, month, region))

    else:
        print(filename,' already exist.')





available_months = ['01','02','03','04','05','06','07','08','09','10','11','12']
available_years = [str(i) for i in range(1999,2017)]
available_regions = ['QLD','NSW','VIC','SA']

for r in available_regions:
    for y in available_years:
        for m in available_months:
            get_data(y, m, region=r)
# Out:
# 1999_01_QLD.csv  already exist.
# 1999_02_QLD.csv  already exist.
# 1999_03_QLD.csv  already exist.
# 1999_04_QLD.csv  already exist.
# 1999_05_QLD.csv  already exist.
# 1999_06_QLD.csv  already exist.
# 1999_07_QLD.csv  already exist.
# 1999_08_QLD.csv  already exist.
# 1999_09_QLD.csv  already exist.
# 1999_10_QLD.csv  already exist.
# 1999_11_QLD.csv  already exist.
# 1999_12_QLD.csv  already exist.
# 2000_01_QLD.csv  already exist.
# 2000_02_QLD.csv  already exist.
# 2000_03_QLD.csv  already exist.
# 2000_04_QLD.csv  already exist.
# 2000_05_QLD.csv  already exist.
# 2000_06_QLD.csv  already exist.
# 2000_07_QLD.csv  already exist.
# 2000_08_QLD.csv  already exist.
# 2000_09_QLD.csv  already exist.
# 2000_10_QLD.csv  already exist.
# 2000_11_QLD.csv  already exist.
# 2000_12_QLD.csv  already exist.
# 2001_01_QLD.csv  already exist.
# 2001_02_QLD.csv  already exist.
# 2001_03_QLD.csv  already exist.
# 2001_04_QLD.csv  already exist.
# 2001_05_QLD.csv  already exist.
# 2001_06_QLD.csv  already exist.
# 2001_07_QLD.csv  already exist.
# 2001_08_QLD.csv  already exist.
# 2001_09_QLD.csv  already exist.
# 2001_10_QLD.csv  already exist.
# 2001_11_QLD.csv  already exist.
# 2001_12_QLD.csv  already exist.
# 2002_01_QLD.csv  already exist.
# 2002_02_QLD.csv  already exist.
# 2002_03_QLD.csv  already exist.
# 2002_04_QLD.csv  already exist.
# 2002_05_QLD.csv  already exist.
# 2002_06_QLD.csv  already exist.
# 2002_07_QLD.csv  already exist.
# 2002_08_QLD.csv  already exist.
# 2002_09_QLD.csv  already exist.
# 2002_10_QLD.csv  already exist.
# 2002_11_QLD.csv  already exist.
# 2002_12_QLD.csv  already exist.
# 2003_01_QLD.csv  already exist.
# 2003_02_QLD.csv  already exist.
# 2003_03_QLD.csv  already exist.
# 2003_04_QLD.csv  already exist.
# 2003_05_QLD.csv  already exist.
# 2003_06_QLD.csv  already exist.
# 2003_07_QLD.csv  already exist.
# 2003_08_QLD.csv  already exist.
# 2003_09_QLD.csv  already exist.
# 2003_10_QLD.csv  already exist.
# 2003_11_QLD.csv  already exist.
# 2003_12_QLD.csv  already exist.
# 2004_01_QLD.csv  already exist.
# 2004_02_QLD.csv  already exist.
# 2004_03_QLD.csv  already exist.
# 2004_04_QLD.csv  already exist.
# 2004_05_QLD.csv  already exist.
# 2004_06_QLD.csv  already exist.
# 2004_07_QLD.csv  already exist.
# 2004_08_QLD.csv  already exist.
# 2004_09_QLD.csv  already exist.
# 2004_10_QLD.csv  already exist.
# 2004_11_QLD.csv  already exist.
# 2004_12_QLD.csv  already exist.
# 2005_01_QLD.csv  already exist.
# 2005_02_QLD.csv  already exist.
# 2005_03_QLD.csv  already exist.
# 2005_04_QLD.csv  already exist.
# 2005_05_QLD.csv  already exist.
# 2005_06_QLD.csv  already exist.
# 2005_07_QLD.csv  already exist.
# 2005_08_QLD.csv  already exist.
# 2005_09_QLD.csv  already exist.
# 2005_10_QLD.csv  already exist.
# 2005_11_QLD.csv  already exist.
# 2005_12_QLD.csv  already exist.
# 2006_01_QLD.csv  already exist.
# 2006_02_QLD.csv  already exist.
# 2006_03_QLD.csv  already exist.
# 2006_04_QLD.csv  already exist.
# 2006_05_QLD.csv  already exist.
# 2006_06_QLD.csv  already exist.
# 2006_07_QLD.csv  already exist.
# 2006_08_QLD.csv  already exist.
# 2006_09_QLD.csv  already exist.
# 2006_10_QLD.csv  already exist.
# 2006_11_QLD.csv  already exist.
# 2006_12_QLD.csv  already exist.
# 2007_01_QLD.csv  already exist.
# 2007_02_QLD.csv  already exist.
# 2007_03_QLD.csv  already exist.
# 2007_04_QLD.csv  already exist.
# 2007_05_QLD.csv  already exist.
# 2007_06_QLD.csv  already exist.
# 2007_07_QLD.csv  already exist.
# 2007_08_QLD.csv  already exist.
# 2007_09_QLD.csv  already exist.
# 2007_10_QLD.csv  already exist.
# 2007_11_QLD.csv  already exist.
# 2007_12_QLD.csv  already exist.
# 2008_01_QLD.csv  already exist.
# 2008_02_QLD.csv  already exist.
# 2008_03_QLD.csv  already exist.
# 2008_04_QLD.csv  already exist.
# 2008_05_QLD.csv  already exist.
# 2008_06_QLD.csv  already exist.
# 2008_07_QLD.csv  already exist.
# 2008_08_QLD.csv  already exist.
# 2008_09_QLD.csv  already exist.
# 2008_10_QLD.csv  already exist.
# 2008_11_QLD.csv  already exist.
# 2008_12_QLD.csv  already exist.
# 2009_01_QLD.csv  already exist.
# 2009_02_QLD.csv  already exist.
# 2009_03_QLD.csv  already exist.
# 2009_04_QLD.csv  already exist.
# 2009_05_QLD.csv  already exist.
# 2009_06_QLD.csv  already exist.
# 2009_07_QLD.csv  already exist.
# 2009_08_QLD.csv  already exist.
# 2009_09_QLD.csv  already exist.
# 2009_10_QLD.csv  already exist.
# 2009_11_QLD.csv  already exist.
# 2009_12_QLD.csv  already exist.
# 2010_01_QLD.csv  already exist.
# 2010_02_QLD.csv  already exist.
# 2010_03_QLD.csv  already exist.
# 2010_04_QLD.csv  already exist.
# 2010_05_QLD.csv  already exist.
# 2010_06_QLD.csv  already exist.
# 2010_07_QLD.csv  already exist.
# 2010_08_QLD.csv  already exist.
# 2010_09_QLD.csv  already exist.
# 2010_10_QLD.csv  already exist.
# 2010_11_QLD.csv  already exist.
# 2010_12_QLD.csv  already exist.
# 2011_01_QLD.csv  already exist.
# 2011_02_QLD.csv  already exist.
# 2011_03_QLD.csv  already exist.
# 2011_04_QLD.csv  already exist.
# 2011_05_QLD.csv  already exist.
# 2011_06_QLD.csv  already exist.
# 2011_07_QLD.csv  already exist.
# 2011_08_QLD.csv  already exist.
# 2011_09_QLD.csv  already exist.
# 2011_10_QLD.csv  already exist.
# 2011_11_QLD.csv  already exist.
# 2011_12_QLD.csv  already exist.
# 2012_01_QLD.csv  already exist.
# 2012_02_QLD.csv  already exist.
# 2012_03_QLD.csv  already exist.
# 2012_04_QLD.csv  already exist.
# 2012_05_QLD.csv  already exist.
# 2012_06_QLD.csv  already exist.
# 2012_07_QLD.csv  already exist.
# 2012_08_QLD.csv  already exist.
# 2012_09_QLD.csv  already exist.
# 2012_10_QLD.csv  already exist.
# 2012_11_QLD.csv  already exist.
# 2012_12_QLD.csv  already exist.
# 2013_01_QLD.csv  already exist.
# 2013_02_QLD.csv  already exist.
# 2013_03_QLD.csv  already exist.
# 2013_04_QLD.csv  already exist.
# 2013_05_QLD.csv  already exist.
# 2013_06_QLD.csv  already exist.
# 2013_07_QLD.csv  already exist.
# 2013_08_QLD.csv  already exist.
# 2013_09_QLD.csv  already exist.
# 2013_10_QLD.csv  already exist.
# 2013_11_QLD.csv  already exist.
# 2013_12_QLD.csv  already exist.
# 2014_01_QLD.csv  already exist.
# 2014_02_QLD.csv  already exist.
# 2014_03_QLD.csv  already exist.
# 2014_04_QLD.csv  already exist.
# 2014_05_QLD.csv  already exist.
# 2014_06_QLD.csv  already exist.
# 2014_07_QLD.csv  already exist.
# 2014_08_QLD.csv  already exist.
# 2014_09_QLD.csv  already exist.
# 2014_10_QLD.csv  already exist.
# 2014_11_QLD.csv  already exist.
# 2014_12_QLD.csv  already exist.
# 2015_01_QLD.csv  already exist.
# 2015_02_QLD.csv  already exist.
# 2015_03_QLD.csv  already exist.
# 2015_04_QLD.csv  already exist.
# 2015_05_QLD.csv  already exist.
# 2015_06_QLD.csv  already exist.
# 2015_07_QLD.csv  already exist.
# 2015_08_QLD.csv  already exist.
# 2015_09_QLD.csv  already exist.
# 2015_10_QLD.csv  already exist.
# 2015_11_QLD.csv  already exist.
# 2015_12_QLD.csv  already exist.
# 2016_01_QLD.csv  already exist.
# 2016_02_QLD.csv  already exist.
# 2016_03_QLD.csv  already exist.
# 2016_04_QLD.csv  already exist.
# 2016_05_QLD.csv  already exist.
# 2016_06_QLD.csv  already exist.
# 2016_07_QLD.csv  already exist.
# 2016_08_QLD.csv  already exist.
# 2016_09_QLD.csv  already exist.
# 2016_10_QLD.csv  already exist.
# 2016_11_QLD.csv  already exist.
# 2016_12_QLD.csv  already exist.
# 1999_01_NSW.csv  already exist.
# 1999_02_NSW.csv  already exist.
# 1999_03_NSW.csv  already exist.
# 1999_04_NSW.csv  already exist.
# 1999_05_NSW.csv  already exist.
# 1999_06_NSW.csv  already exist.
# 1999_07_NSW.csv  already exist.
# 1999_08_NSW.csv  already exist.
# 1999_09_NSW.csv  already exist.
# 1999_10_NSW.csv  already exist.
# 1999_11_NSW.csv  already exist.
# 1999_12_NSW.csv  already exist.
# 2000_01_NSW.csv  already exist.
# 2000_02_NSW.csv  already exist.
# 2000_03_NSW.csv  already exist.
# 2000_04_NSW.csv  already exist.
# 2000_05_NSW.csv  already exist.
# 2000_06_NSW.csv  already exist.
# 2000_07_NSW.csv  already exist.
# 2000_08_NSW.csv  already exist.
# 2000_09_NSW.csv  already exist.
# 2000_10_NSW.csv  already exist.
# 2000_11_NSW.csv  already exist.
# 2000_12_NSW.csv  already exist.
# 2001_01_NSW.csv  already exist.
# 2001_02_NSW.csv  already exist.
# 2001_03_NSW.csv  already exist.
# 2001_04_NSW.csv  already exist.
# 2001_05_NSW.csv  already exist.
# 2001_06_NSW.csv  already exist.
# 2001_07_NSW.csv  already exist.
# 2001_08_NSW.csv  already exist.
# 2001_09_NSW.csv  already exist.
# 2001_10_NSW.csv  already exist.
# 2001_11_NSW.csv  already exist.
# 2001_12_NSW.csv  already exist.
# 2002_01_NSW.csv  already exist.
# 2002_02_NSW.csv  already exist.
# 2002_03_NSW.csv  already exist.
# 2002_04_NSW.csv  already exist.
# 2002_05_NSW.csv  already exist.
# 2002_06_NSW.csv  already exist.
# 2002_07_NSW.csv  already exist.
# 2002_08_NSW.csv  already exist.
# 2002_09_NSW.csv  already exist.
# 2002_10_NSW.csv  already exist.
# 2002_11_NSW.csv  already exist.
# 2002_12_NSW.csv  already exist.
# 2003_01_NSW.csv  already exist.
# 2003_02_NSW.csv  already exist.
# 2003_03_NSW.csv  already exist.
# 2003_04_NSW.csv  already exist.
# 2003_05_NSW.csv  already exist.
# 2003_06_NSW.csv  already exist.
# 2003_07_NSW.csv  already exist.
# 2003_08_NSW.csv  already exist.
# 2003_09_NSW.csv  already exist.
# 2003_10_NSW.csv  already exist.
# 2003_11_NSW.csv  already exist.
# 2003_12_NSW.csv  already exist.
# 2004_01_NSW.csv  already exist.
# 2004_02_NSW.csv  already exist.
# 2004_03_NSW.csv  already exist.
# 2004_04_NSW.csv  already exist.
# 2004_05_NSW.csv  already exist.
# 2004_06_NSW.csv  already exist.
# 2004_07_NSW.csv  already exist.
# 2004_08_NSW.csv  already exist.
# 2004_09_NSW.csv  already exist.
# 2004_10_NSW.csv  already exist.
# 2004_11_NSW.csv  already exist.
# 2004_12_NSW.csv  already exist.
# 2005_01_NSW.csv  already exist.
# 2005_02_NSW.csv  already exist.
# 2005_03_NSW.csv  already exist.
# 2005_04_NSW.csv  already exist.
# 2005_05_NSW.csv  already exist.
# 2005_06_NSW.csv  already exist.
# 2005_07_NSW.csv  already exist.
# 2005_08_NSW.csv  already exist.
# 2005_09_NSW.csv  already exist.
# 2005_10_NSW.csv  already exist.
# 2005_11_NSW.csv  already exist.
# 2005_12_NSW.csv  already exist.
# 2006_01_NSW.csv  already exist.
# 2006_02_NSW.csv  already exist.
# 2006_03_NSW.csv  already exist.
# 2006_04_NSW.csv  already exist.
# 2006_05_NSW.csv  already exist.
# 2006_06_NSW.csv  already exist.
# 2006_07_NSW.csv  already exist.
# 2006_08_NSW.csv  already exist.
# 2006_09_NSW.csv  already exist.
# 2006_10_NSW.csv  already exist.
# 2006_11_NSW.csv  already exist.
# 2006_12_NSW.csv  already exist.
# 2007_01_NSW.csv  already exist.
# 2007_02_NSW.csv  already exist.
# 2007_03_NSW.csv  already exist.
# 2007_04_NSW.csv  already exist.
# 2007_05_NSW.csv  already exist.
# 2007_06_NSW.csv  already exist.
# 2007_07_NSW.csv  already exist.
# 2007_08_NSW.csv  already exist.
# 2007_09_NSW.csv  already exist.
# 2007_10_NSW.csv  already exist.
# 2007_11_NSW.csv  already exist.
# 2007_12_NSW.csv  already exist.
# 2008_01_NSW.csv  already exist.
# 2008_02_NSW.csv  already exist.
# 2008_03_NSW.csv  already exist.
# 2008_04_NSW.csv  already exist.
# 2008_05_NSW.csv  already exist.
# 2008_06_NSW.csv  already exist.
# 2008_07_NSW.csv  already exist.
# 2008_08_NSW.csv  already exist.
# 2008_09_NSW.csv  already exist.
# 2008_10_NSW.csv  already exist.
# 2008_11_NSW.csv  already exist.
# 2008_12_NSW.csv  already exist.
# 2009_01_NSW.csv  already exist.
# 2009_02_NSW.csv  already exist.
# 2009_03_NSW.csv  already exist.
# 2009_04_NSW.csv  already exist.
# 2009_05_NSW.csv  already exist.
# 2009_06_NSW.csv  already exist.
# 2009_07_NSW.csv  already exist.
# 2009_08_NSW.csv  already exist.
# 2009_09_NSW.csv  already exist.
# 2009_10_NSW.csv  already exist.
# 2009_11_NSW.csv  already exist.
# 2009_12_NSW.csv  already exist.
# 2010_01_NSW.csv  already exist.
# 2010_02_NSW.csv  already exist.
# 2010_03_NSW.csv  already exist.
# 2010_04_NSW.csv  already exist.
# 2010_05_NSW.csv  already exist.
# 2010_06_NSW.csv  already exist.
# 2010_07_NSW.csv  already exist.
# 2010_08_NSW.csv  already exist.
# 2010_09_NSW.csv  already exist.
# 2010_10_NSW.csv  already exist.
# 2010_11_NSW.csv  already exist.
# 2010_12_NSW.csv  already exist.
# 2011_01_NSW.csv  already exist.
# 2011_02_NSW.csv  already exist.
# 2011_03_NSW.csv  already exist.
# 2011_04_NSW.csv  already exist.
# 2011_05_NSW.csv  already exist.
# 2011_06_NSW.csv  already exist.
# 2011_07_NSW.csv  already exist.
# 2011_08_NSW.csv  already exist.
# 2011_09_NSW.csv  already exist.
# 2011_10_NSW.csv  already exist.
# 2011_11_NSW.csv  already exist.
# 2011_12_NSW.csv  already exist.
# 2012_01_NSW.csv  already exist.
# 2012_02_NSW.csv  already exist.
# 2012_03_NSW.csv  already exist.
# 2012_04_NSW.csv  already exist.
# 2012_05_NSW.csv  already exist.
# 2012_06_NSW.csv  already exist.
# 2012_07_NSW.csv  already exist.
# 2012_08_NSW.csv  already exist.
# 2012_09_NSW.csv  already exist.
# 2012_10_NSW.csv  already exist.
# 2012_11_NSW.csv  already exist.
# 2012_12_NSW.csv  already exist.
# 2013_01_NSW.csv  already exist.
# 2013_02_NSW.csv  already exist.
# 2013_03_NSW.csv  already exist.
# 2013_04_NSW.csv  already exist.
# 2013_05_NSW.csv  already exist.
# 2013_06_NSW.csv  already exist.
# 2013_07_NSW.csv  already exist.
# 2013_08_NSW.csv  already exist.
# 2013_09_NSW.csv  already exist.
# 2013_10_NSW.csv  already exist.
# 2013_11_NSW.csv  already exist.
# 2013_12_NSW.csv  already exist.
# 2014_01_NSW.csv  already exist.
# 2014_02_NSW.csv  already exist.
# 2014_03_NSW.csv  already exist.
# 2014_04_NSW.csv  already exist.
# 2014_05_NSW.csv  already exist.
# 2014_06_NSW.csv  already exist.
# 2014_07_NSW.csv  already exist.
# 2014_08_NSW.csv  already exist.
# 2014_09_NSW.csv  already exist.
# 2014_10_NSW.csv  already exist.
# 2014_11_NSW.csv  already exist.
# 2014_12_NSW.csv  already exist.
# 2015_01_NSW.csv  already exist.
# 2015_02_NSW.csv  already exist.
# 2015_03_NSW.csv  already exist.
# 2015_04_NSW.csv  already exist.
# 2015_05_NSW.csv  already exist.
# 2015_06_NSW.csv  already exist.
# 2015_07_NSW.csv  already exist.
# 2015_08_NSW.csv  already exist.
# 2015_09_NSW.csv  already exist.
# 2015_10_NSW.csv  already exist.
# 2015_11_NSW.csv  already exist.
# 2015_12_NSW.csv  already exist.
# 2016_01_NSW.csv  already exist.
# 2016_02_NSW.csv  already exist.
# 2016_03_NSW.csv  already exist.
# 2016_04_NSW.csv  already exist.
# 2016_05_NSW.csv  already exist.
# 2016_06_NSW.csv  already exist.
# 2016_07_NSW.csv  already exist.
# 2016_08_NSW.csv  already exist.
# 2016_09_NSW.csv  already exist.
# 2016_10_NSW.csv  already exist.
# 2016_11_NSW.csv  already exist.
# 2016_12_NSW.csv  already exist.
# 1999_01_VIC.csv  already exist.
# 1999_02_VIC.csv  already exist.
# 1999_03_VIC.csv  already exist.
# 1999_04_VIC.csv  already exist.
# 1999_05_VIC.csv  already exist.
# 1999_06_VIC.csv  already exist.
# 1999_07_VIC.csv  already exist.
# 1999_08_VIC.csv  already exist.
# 1999_09_VIC.csv  already exist.
# 1999_10_VIC.csv  already exist.
# 1999_11_VIC.csv  already exist.
# 1999_12_VIC.csv  already exist.
# 2000_01_VIC.csv  already exist.
# 2000_02_VIC.csv  already exist.
# 2000_03_VIC.csv  already exist.
# 2000_04_VIC.csv  already exist.
# 2000_05_VIC.csv  already exist.
# 2000_06_VIC.csv  already exist.
# 2000_07_VIC.csv  already exist.
# 2000_08_VIC.csv  already exist.
# 2000_09_VIC.csv  already exist.
# 2000_10_VIC.csv  already exist.
# 2000_11_VIC.csv  already exist.
# 2000_12_VIC.csv  already exist.
# 2001_01_VIC.csv  already exist.
# 2001_02_VIC.csv  already exist.
# 2001_03_VIC.csv  already exist.
# 2001_04_VIC.csv  already exist.
# 2001_05_VIC.csv  already exist.
# 2001_06_VIC.csv  already exist.
# 2001_07_VIC.csv  already exist.
# 2001_08_VIC.csv  already exist.
# 2001_09_VIC.csv  already exist.
# 2001_10_VIC.csv  already exist.
# 2001_11_VIC.csv  already exist.
# 2001_12_VIC.csv  already exist.
# 2002_01_VIC.csv  already exist.
# 2002_02_VIC.csv  already exist.
# 2002_03_VIC.csv  already exist.
# 2002_04_VIC.csv  already exist.
# 2002_05_VIC.csv  already exist.
# 2002_06_VIC.csv  already exist.
# 2002_07_VIC.csv  already exist.
# 2002_08_VIC.csv  already exist.
# 2002_09_VIC.csv  already exist.
# 2002_10_VIC.csv  already exist.
# 2002_11_VIC.csv  already exist.
# 2002_12_VIC.csv  already exist.
# 2003_01_VIC.csv  already exist.
# 2003_02_VIC.csv  already exist.
# 2003_03_VIC.csv  already exist.
# 2003_04_VIC.csv  already exist.
# 2003_05_VIC.csv  already exist.
# 2003_06_VIC.csv  already exist.
# 2003_07_VIC.csv  already exist.
# 2003_08_VIC.csv  already exist.
# 2003_09_VIC.csv  already exist.
# 2003_10_VIC.csv  already exist.
# 2003_11_VIC.csv  already exist.
# 2003_12_VIC.csv  already exist.
# 2004_01_VIC.csv  already exist.
# 2004_02_VIC.csv  already exist.
# 2004_03_VIC.csv  already exist.
# 2004_04_VIC.csv  already exist.
# 2004_05_VIC.csv  already exist.
# 2004_06_VIC.csv  already exist.
# 2004_07_VIC.csv  already exist.
# 2004_08_VIC.csv  already exist.
# 2004_09_VIC.csv  already exist.
# 2004_10_VIC.csv  already exist.
# 2004_11_VIC.csv  already exist.
# 2004_12_VIC.csv  already exist.
# 2005_01_VIC.csv  already exist.
# 2005_02_VIC.csv  already exist.
# 2005_03_VIC.csv  already exist.
# 2005_04_VIC.csv  already exist.
# 2005_05_VIC.csv  already exist.
# 2005_06_VIC.csv  already exist.
# 2005_07_VIC.csv  already exist.
# 2005_08_VIC.csv  already exist.
# 2005_09_VIC.csv  already exist.
# 2005_10_VIC.csv  already exist.
# 2005_11_VIC.csv  already exist.
# 2005_12_VIC.csv  already exist.
# 2006_01_VIC.csv  already exist.
# 2006_02_VIC.csv  already exist.
# 2006_03_VIC.csv  already exist.
# 2006_04_VIC.csv  already exist.
# 2006_05_VIC.csv  already exist.
# 2006_06_VIC.csv  already exist.
# 2006_07_VIC.csv  already exist.
# 2006_08_VIC.csv  already exist.
# 2006_09_VIC.csv  already exist.
# 2006_10_VIC.csv  already exist.
# 2006_11_VIC.csv  already exist.
# 2006_12_VIC.csv  already exist.
# 2007_01_VIC.csv  already exist.
# 2007_02_VIC.csv  already exist.
# 2007_03_VIC.csv  already exist.
# 2007_04_VIC.csv  already exist.
# 2007_05_VIC.csv  already exist.
# 2007_06_VIC.csv  already exist.
# 2007_07_VIC.csv  already exist.
# 2007_08_VIC.csv  already exist.
# 2007_09_VIC.csv  already exist.
# 2007_10_VIC.csv  already exist.
# 2007_11_VIC.csv  already exist.
# 2007_12_VIC.csv  already exist.
# 2008_01_VIC.csv  already exist.
# 2008_02_VIC.csv  already exist.
# 2008_03_VIC.csv  already exist.
# 2008_04_VIC.csv  already exist.
# 2008_05_VIC.csv  already exist.
# 2008_06_VIC.csv  already exist.
# 2008_07_VIC.csv  already exist.
# 2008_08_VIC.csv  already exist.
# 2008_09_VIC.csv  already exist.
# 2008_10_VIC.csv  already exist.
# 2008_11_VIC.csv  already exist.
# 2008_12_VIC.csv  already exist.
# 2009_01_VIC.csv  already exist.
# 2009_02_VIC.csv  already exist.
# 2009_03_VIC.csv  already exist.
# 2009_04_VIC.csv  already exist.
# 2009_05_VIC.csv  already exist.
# 2009_06_VIC.csv  already exist.
# 2009_07_VIC.csv  already exist.
# 2009_08_VIC.csv  already exist.
# 2009_09_VIC.csv  already exist.
# 2009_10_VIC.csv  already exist.
# 2009_11_VIC.csv  already exist.
# 2009_12_VIC.csv  already exist.
# 2010_01_VIC.csv  already exist.
# 2010_02_VIC.csv  already exist.
# 2010_03_VIC.csv  already exist.
# 2010_04_VIC.csv  already exist.
# 2010_05_VIC.csv  already exist.
# 2010_06_VIC.csv  already exist.
# 2010_07_VIC.csv  already exist.
# 2010_08_VIC.csv  already exist.
# 2010_09_VIC.csv  already exist.
# 2010_10_VIC.csv  already exist.
# 2010_11_VIC.csv  already exist.
# 2010_12_VIC.csv  already exist.
# 2011_01_VIC.csv  already exist.
# 2011_02_VIC.csv  already exist.
# 2011_03_VIC.csv  already exist.
# 2011_04_VIC.csv  already exist.
# 2011_05_VIC.csv  already exist.
# 2011_06_VIC.csv  already exist.
# 2011_07_VIC.csv  already exist.
# 2011_08_VIC.csv  already exist.
# 2011_09_VIC.csv  already exist.
# 2011_10_VIC.csv  already exist.
# 2011_11_VIC.csv  already exist.
# 2011_12_VIC.csv  already exist.
# 2012_01_VIC.csv  already exist.
# 2012_02_VIC.csv  already exist.
# 2012_03_VIC.csv  already exist.
# 2012_04_VIC.csv  already exist.
# 2012_05_VIC.csv  already exist.
# 2012_06_VIC.csv  already exist.
# 2012_07_VIC.csv  already exist.
# 2012_08_VIC.csv  already exist.
# 2012_09_VIC.csv  already exist.
# 2012_10_VIC.csv  already exist.
# 2012_11_VIC.csv  already exist.
# 2012_12_VIC.csv  already exist.
# 2013_01_VIC.csv  already exist.
# 2013_02_VIC.csv  already exist.
# 2013_03_VIC.csv  already exist.
# 2013_04_VIC.csv  already exist.
# 2013_05_VIC.csv  already exist.
# 2013_06_VIC.csv  already exist.
# 2013_07_VIC.csv  already exist.
# 2013_08_VIC.csv  already exist.
# 2013_09_VIC.csv  already exist.
# 2013_10_VIC.csv  already exist.
# 2013_11_VIC.csv  already exist.
# 2013_12_VIC.csv  already exist.
# 2014_01_VIC.csv  already exist.
# 2014_02_VIC.csv  already exist.
# 2014_03_VIC.csv  already exist.
# 2014_04_VIC.csv  already exist.
# 2014_05_VIC.csv  already exist.
# 2014_06_VIC.csv  already exist.
# 2014_07_VIC.csv  already exist.
# 2014_08_VIC.csv  already exist.
# 2014_09_VIC.csv  already exist.
# 2014_10_VIC.csv  already exist.
# 2014_11_VIC.csv  already exist.
# 2014_12_VIC.csv  already exist.
# 2015_01_VIC.csv  already exist.
# 2015_02_VIC.csv  already exist.
# 2015_03_VIC.csv  already exist.
# 2015_04_VIC.csv  already exist.
# 2015_05_VIC.csv  already exist.
# 2015_06_VIC.csv  already exist.
# 2015_07_VIC.csv  already exist.
# 2015_08_VIC.csv  already exist.
# 2015_09_VIC.csv  already exist.
# 2015_10_VIC.csv  already exist.
# 2015_11_VIC.csv  already exist.
# 2015_12_VIC.csv  already exist.
# 2016_01_VIC.csv  already exist.
# 2016_02_VIC.csv  already exist.
# 2016_03_VIC.csv  already exist.
# 2016_04_VIC.csv  already exist.
# 2016_05_VIC.csv  already exist.
# 2016_06_VIC.csv  already exist.
# 2016_07_VIC.csv  already exist.
# 2016_08_VIC.csv  already exist.
# 2016_09_VIC.csv  already exist.
# 2016_10_VIC.csv  already exist.
# 2016_11_VIC.csv  already exist.
# 2016_12_VIC.csv  already exist.
# 1999_01_SA.csv  already exist.
# 1999_02_SA.csv  already exist.
# 1999_03_SA.csv  already exist.
# 1999_04_SA.csv  already exist.
# 1999_05_SA.csv  already exist.
# 1999_06_SA.csv  already exist.
# 1999_07_SA.csv  already exist.
# 1999_08_SA.csv  already exist.
# 1999_09_SA.csv  already exist.
# 1999_10_SA.csv  already exist.
# 1999_11_SA.csv  already exist.
# 1999_12_SA.csv  already exist.
# 2000_01_SA.csv  already exist.
# 2000_02_SA.csv  already exist.
# 2000_03_SA.csv  already exist.
# 2000_04_SA.csv  already exist.
# 2000_05_SA.csv  already exist.
# 2000_06_SA.csv  already exist.
# 2000_07_SA.csv  already exist.
# 2000_08_SA.csv  already exist.
# 2000_09_SA.csv  already exist.
# 2000_10_SA.csv  already exist.
# 2000_11_SA.csv  already exist.
# 2000_12_SA.csv  already exist.
# 2001_01_SA.csv  already exist.
# 2001_02_SA.csv  already exist.
# 2001_03_SA.csv  already exist.
# 2001_04_SA.csv  already exist.
# 2001_05_SA.csv  already exist.
# 2001_06_SA.csv  already exist.
# 2001_07_SA.csv  already exist.
# 2001_08_SA.csv  already exist.
# 2001_09_SA.csv  already exist.
# 2001_10_SA.csv  already exist.
# 2001_11_SA.csv  already exist.
# 2001_12_SA.csv  already exist.
# 2002_01_SA.csv  already exist.
# 2002_02_SA.csv  already exist.
# 2002_03_SA.csv  already exist.
# 2002_04_SA.csv  already exist.
# 2002_05_SA.csv  already exist.
# 2002_06_SA.csv  already exist.
# 2002_07_SA.csv  already exist.
# 2002_08_SA.csv  already exist.
# 2002_09_SA.csv  already exist.
# 2002_10_SA.csv  already exist.
# 2002_11_SA.csv  already exist.
# 2002_12_SA.csv  already exist.
# 2003_01_SA.csv  already exist.
# 2003_02_SA.csv  already exist.
# 2003_03_SA.csv  already exist.
# 2003_04_SA.csv  already exist.
# 2003_05_SA.csv  already exist.
# 2003_06_SA.csv  already exist.
# 2003_07_SA.csv  already exist.
# 2003_08_SA.csv  already exist.
# 2003_09_SA.csv  already exist.
# 2003_10_SA.csv  already exist.
# 2003_11_SA.csv  already exist.
# 2003_12_SA.csv  already exist.
# 2004_01_SA.csv  already exist.
# 2004_02_SA.csv  already exist.
# 2004_03_SA.csv  already exist.
# 2004_04_SA.csv  already exist.
# 2004_05_SA.csv  already exist.
# 2004_06_SA.csv  already exist.
# 2004_07_SA.csv  already exist.
# 2004_08_SA.csv  already exist.
# 2004_09_SA.csv  already exist.
# 2004_10_SA.csv  already exist.
# 2004_11_SA.csv  already exist.
# 2004_12_SA.csv  already exist.
# 2005_01_SA.csv  already exist.
# 2005_02_SA.csv  already exist.
# 2005_03_SA.csv  already exist.
# 2005_04_SA.csv  already exist.
# 2005_05_SA.csv  already exist.
# 2005_06_SA.csv  already exist.
# 2005_07_SA.csv  already exist.
# 2005_08_SA.csv  already exist.
# 2005_09_SA.csv  already exist.
# 2005_10_SA.csv  already exist.
# 2005_11_SA.csv  already exist.
# 2005_12_SA.csv  already exist.
# 2006_01_SA.csv  already exist.
# 2006_02_SA.csv  already exist.
# 2006_03_SA.csv  already exist.
# 2006_04_SA.csv  already exist.
# 2006_05_SA.csv  already exist.
# 2006_06_SA.csv  already exist.
# 2006_07_SA.csv  already exist.
# 2006_08_SA.csv  already exist.
# 2006_09_SA.csv  already exist.
# 2006_10_SA.csv  already exist.
# 2006_11_SA.csv  already exist.
# 2006_12_SA.csv  already exist.
# 2007_01_SA.csv  already exist.
# 2007_02_SA.csv  already exist.
# 2007_03_SA.csv  already exist.
# 2007_04_SA.csv  already exist.
# 2007_05_SA.csv  already exist.
# 2007_06_SA.csv  already exist.
# 2007_07_SA.csv  already exist.
# 2007_08_SA.csv  already exist.
# 2007_09_SA.csv  already exist.
# 2007_10_SA.csv  already exist.
# 2007_11_SA.csv  already exist.
# 2007_12_SA.csv  already exist.
# 2008_01_SA.csv  already exist.
# 2008_02_SA.csv  already exist.
# 2008_03_SA.csv  already exist.
# 2008_04_SA.csv  already exist.
# 2008_05_SA.csv  already exist.
# 2008_06_SA.csv  already exist.
# 2008_07_SA.csv  already exist.
# 2008_08_SA.csv  already exist.
# 2008_09_SA.csv  already exist.
# 2008_10_SA.csv  already exist.
# 2008_11_SA.csv  already exist.
# 2008_12_SA.csv  already exist.
# 2009_01_SA.csv  already exist.
# 2009_02_SA.csv  already exist.
# 2009_03_SA.csv  already exist.
# 2009_04_SA.csv  already exist.
# 2009_05_SA.csv  already exist.
# 2009_06_SA.csv  already exist.
# 2009_07_SA.csv  already exist.
# 2009_08_SA.csv  already exist.
# 2009_09_SA.csv  already exist.
# 2009_10_SA.csv  already exist.
# 2009_11_SA.csv  already exist.
# 2009_12_SA.csv  already exist.
# 2010_01_SA.csv  already exist.
# 2010_02_SA.csv  already exist.
# 2010_03_SA.csv  already exist.
# 2010_04_SA.csv  already exist.
# 2010_05_SA.csv  already exist.
# 2010_06_SA.csv  already exist.
# 2010_07_SA.csv  already exist.
# 2010_08_SA.csv  already exist.
# 2010_09_SA.csv  already exist.
# 2010_10_SA.csv  already exist.
# 2010_11_SA.csv  already exist.
# 2010_12_SA.csv  already exist.
# 2011_01_SA.csv  already exist.
# 2011_02_SA.csv  already exist.
# 2011_03_SA.csv  already exist.
# 2011_04_SA.csv  already exist.
# 2011_05_SA.csv  already exist.
# 2011_06_SA.csv  already exist.
# 2011_07_SA.csv  already exist.
# 2011_08_SA.csv  already exist.
# 2011_09_SA.csv  already exist.
# 2011_10_SA.csv  already exist.
# 2011_11_SA.csv  already exist.
# 2011_12_SA.csv  already exist.
# 2012_01_SA.csv  already exist.
# 2012_02_SA.csv  already exist.
# 2012_03_SA.csv  already exist.
# 2012_04_SA.csv  already exist.
# 2012_05_SA.csv  already exist.
# 2012_06_SA.csv  already exist.
# 2012_07_SA.csv  already exist.
# 2012_08_SA.csv  already exist.
# 2012_09_SA.csv  already exist.
# 2012_10_SA.csv  already exist.
# 2012_11_SA.csv  already exist.
# 2012_12_SA.csv  already exist.
# 2013_01_SA.csv  already exist.
# 2013_02_SA.csv  already exist.
# 2013_03_SA.csv  already exist.
# 2013_04_SA.csv  already exist.
# 2013_05_SA.csv  already exist.
# 2013_06_SA.csv  already exist.
# 2013_07_SA.csv  already exist.
# 2013_08_SA.csv  already exist.
# 2013_09_SA.csv  already exist.
# 2013_10_SA.csv  already exist.
# 2013_11_SA.csv  already exist.
# 2013_12_SA.csv  already exist.
# 2014_01_SA.csv  already exist.
# 2014_02_SA.csv  already exist.
# 2014_03_SA.csv  already exist.
# 2014_04_SA.csv  already exist.
# 2014_05_SA.csv  already exist.
# 2014_06_SA.csv  already exist.
# 2014_07_SA.csv  already exist.
# 2014_08_SA.csv  already exist.
# 2014_09_SA.csv  already exist.
# 2014_10_SA.csv  already exist.
# 2014_11_SA.csv  already exist.
# 2014_12_SA.csv  already exist.
# 2015_01_SA.csv  already exist.
# 2015_02_SA.csv  already exist.
# 2015_03_SA.csv  already exist.
# 2015_04_SA.csv  already exist.
# 2015_05_SA.csv  already exist.
# 2015_06_SA.csv  already exist.
# 2015_07_SA.csv  already exist.
# 2015_08_SA.csv  already exist.
# 2015_09_SA.csv  already exist.
# 2015_10_SA.csv  already exist.
# 2015_11_SA.csv  already exist.
# 2015_12_SA.csv  already exist.
# 2016_01_SA.csv  already exist.
# 2016_02_SA.csv  already exist.
# 2016_03_SA.csv  already exist.
# 2016_04_SA.csv  already exist.
# 2016_05_SA.csv  already exist.
# 2016_06_SA.csv  already exist.
# 2016_07_SA.csv  already exist.
# 2016_08_SA.csv  already exist.
# 2016_09_SA.csv  already exist.
# 2016_10_SA.csv  already exist.
# 2016_11_SA.csv  already exist.
# 2016_12_SA.csv  already exist.

# %%
df1 = pd.read_csv('data/NSW/1999_01_NSW.csv')
df1 = df1.drop(labels=df1.columns[0], axis=1)
df1.head()
# Out:
#   REGION    SETTLEMENTDATE  TOTALDEMAND    RRP PERIODTYPE
# 0   NSW1  1999/01/01 00:30   6820.56000  27.64      TRADE
# 1   NSW1  1999/01/01 01:00   6421.34833  26.64      TRADE
# 2   NSW1  1999/01/01 01:30   5991.45000  25.81      TRADE
# 3   NSW1  1999/01/01 02:00   5663.07333  19.94      TRADE
# 4   NSW1  1999/01/01 02:30   5384.04667  19.48      TRADE

# %%
df2 = pd.read_csv('data/NSW/1999_02_NSW.csv')

df2 = df2.drop(labels=df2.columns[0], axis=1)
df2.head()
# Out:
#   REGION    SETTLEMENTDATE  TOTALDEMAND    RRP PERIODTYPE
# 0   NSW1  1999/02/01 00:30   6135.45833  14.71      TRADE
# 1   NSW1  1999/02/01 01:00   5973.37333  14.50      TRADE
# 2   NSW1  1999/02/01 01:30   5803.53167  16.20      TRADE
# 3   NSW1  1999/02/01 02:00   5558.06500  14.38      TRADE
# 4   NSW1  1999/02/01 02:30   5378.94833  14.27      TRADE

# %%
df_total = pd.DataFrame()
df1 = pd.read_csv('data/NSW/1999_01_NSW.csv')

df_total = df_total.append(df1)

df_total.head()
# Out:
#    Unnamed: 0 REGION    SETTLEMENTDATE  TOTALDEMAND    RRP PERIODTYPE
# 0           0   NSW1  1999/01/01 00:30   6820.56000  27.64      TRADE
# 1           1   NSW1  1999/01/01 01:00   6421.34833  26.64      TRADE
# 2           2   NSW1  1999/01/01 01:30   5991.45000  25.81      TRADE
# 3           3   NSW1  1999/01/01 02:00   5663.07333  19.94      TRADE
# 4           4   NSW1  1999/01/01 02:30   5384.04667  19.48      TRADE

# %%
# merge dataset into 1 big dataset.
def merge_data(path='data', region='QLD', save=True):
    
   
    available_months = ['01','02','03','04','05','06','07','08','09','10','11','12']
    available_years = [str(i) for i in range(1999,2017)]
    
    available_filenames = []
    
    for y in available_years:
        for m in available_months:
            available_filenames.append("{}/{}/{}_{}_{}.csv".format(path,region,y, m, region))
    
    df_total = pd.DataFrame()
    for filename in available_filenames:
        df_cur = pd.read_csv(filename)
        df_total = df_total.append(df_cur)
        

    df_total = df_total.drop(labels=df_total.columns[0], axis=1)
    df_total = df_total.reset_index(drop=True)
    
    if save:
        df_total.to_csv('{}/{}_all.csv'.format(path,region))
    
    return df_total
